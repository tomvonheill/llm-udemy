# %%
from transformers import BertTokenizer, BertModel
import torch
from bertviz import head_view
import pandas as pd

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# %%
text = "My friend told me about htis class and I love it so far! she was right."

tokens = tokenizer.encode(text)
inputs = torch.tensor(tokens).unsqueeze(0)
inputs
# Out:
# tensor([[ 101, 2026, 2767, 2409, 2033, 2055, 1044, 7315, 2465, 1998, 1045, 2293,
#          2009, 2061, 2521,  999, 2016, 2001, 2157, 1012,  102]])

# %%
attention = model(inputs, output_attentions=True)[2]

# %%
final_attention = attention[-1].mean(1)[0]

# %%
attention_df = pd.DataFrame(final_attention.detach()).applymap(float).round(3)
attention_df.columns = tokenizer.convert_ids_to_tokens(tokens)
attention_df.index=tokenizer.convert_ids_to_tokens(tokens)
attention_df
# Out:
# /var/folders/9y/p5rv7rqx75j18s_3ttrlnxrw0000gq/T/ipykernel_55573/2405573634.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   attention_df = pd.DataFrame(final_attention.detach()).applymap(float).round(3)
#         [CLS]     my  friend   told     me  about      h  ##tis  class    and  \
# [CLS]   0.085  0.030   0.017  0.013  0.012  0.030  0.048  0.070  0.057  0.035
# my      0.022  0.026   0.015  0.010  0.012  0.025  0.020  0.015  0.014  0.017
# friend  0.018  0.010   0.119  0.008  0.005  0.006  0.012  0.008  0.011  0.009
# told    0.010  0.005   0.011  0.082  0.004  0.011  0.004  0.002  0.006  0.006
# me      0.027  0.016   0.013  0.012  0.017  0.017  0.012  0.010  0.011  0.018
# about   0.019  0.009   0.004  0.010  0.008  0.081  0.016  0.009  0.018  0.012
# h       0.035  0.005   0.002  0.001  0.002  0.007  0.158  0.060  0.025  0.008
# ##tis   0.024  0.005   0.001  0.001  0.002  0.006  0.055  0.130  0.030  0.005
# class   0.030  0.012   0.005  0.006  0.008  0.022  0.042  0.054  0.102  0.014
# and     0.031  0.017   0.006  0.006  0.012  0.010  0.013  0.007  0.009  0.095
# i       0.024  0.014   0.008  0.005  0.009  0.015  0.026  0.015  0.014  0.026
# love    0.015  0.006   0.005  0.006  0.004  0.013  0.014  0.008  0.012  0.009
# it      0.021  0.007   0.004  0.005  0.007  0.033  0.028  0.030  0.038  0.013
# so      0.021  0.015   0.007  0.010  0.017  0.031  0.023  0.019  0.018  0.015
# far     0.016  0.009   0.008  0.009  0.011  0.026  0.019  0.012  0.018  0.018
# !       0.037  0.014   0.005  0.005  0.007  0.010  0.010  0.008  0.008  0.031
# she     0.029  0.012   0.035  0.022  0.009  0.006  0.010  0.006  0.008  0.018
# was     0.024  0.012   0.030  0.012  0.009  0.006  0.009  0.007  0.008  0.014
# right   0.053  0.009   0.006  0.008  0.007  0.007  0.003  0.002  0.004  0.007
